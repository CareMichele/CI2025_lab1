# %% [markdown]
# Copyright **`(c)`** 2025 Giovanni Squillero `<giovanni.squillero@polito.it>`
# [`https://github.com/squillero/computational-intelligence`](https://github.com/squillero/computational-intelligence)
# Free under certain conditions — see the [`license`](https://github.com/squillero/computational-intelligence/blob/master/LICENSE.md) for details.

# %%
import numpy as np
from icecream import ic

# %%
class Solution:
    
    def __init__(self, n_knapsacks, n_items, n_dimensions, values, weights, constraints):
        self.n_knapsacks = n_knapsacks
        self.n_items = n_items
        self.n_dimensions = n_dimensions
        self.values = values
        self.weights = weights
        self.constraints = constraints
        self.penalty_weight = values.max() * 2
        
    # Check that the same object does not appear in multiple knapsacks
    def checkSameObject(self, solution, index):
        return np.any(solution[:, index])
    '''
    # Check if the solution is valid
    def is_valid(self, solution, knapsack):
        items = solution[knapsack, :]
        tot_weights = self.weights[items, :].sum(axis=0)
        #True if no constraint is exceeded
        return np.all(tot_weights <= self.constraints[knapsack, :])
    '''
    def fitness(self, solution):
        total_value = 0  # sum of values of objects of all knapsacks 
        penalty = 0 

        for k in range(self.n_knapsacks):
            items = solution[k, :]
            total_value += self.values[items].sum()

            # penalty if it exceeds the limits
            tot_w = self.weights[items, :].sum(axis=0)
            over = np.maximum(tot_w - self.constraints[k, :], 0)
            penalty += over.sum() * 10  # proportional penalty

        # penalty if one object is in more knapsacks
        if np.any(solution.sum(axis=0) > 1):
            penalty += self.penalty_weight

        return total_value - penalty
    
    def tweak(self, solution):
        k = np.random.randint(0, self.n_knapsacks)
        i = np.random.randint(0, self.n_items)

        # if object already assigned, remove it
        # otherwise, put it in knapsack k
        if self.checkSameObject(solution, i):
            solution[:, i] = False
        else:
            solution[k, i] = True
    
    def resolve(self, max_steps, initial_temp, cooling_rate, verbose = True):
        # Initialize with empty solution
        solution = np.zeros((self.n_knapsacks, self.n_items), dtype=bool)
        
        # SA parameters
        T = initial_temp
        
        current_fitness = self.fitness(solution)
        best_fitness = current_fitness
        best_solution = solution.copy()

        for step in range(max_steps):
            # save previous state 
            old_solution = solution.copy()
            old_fitness = current_fitness
            
            # add/remove random object
            self.tweak(solution)

            new_fitness = self.fitness(solution)
            delta = new_fitness - old_fitness

            #SA
            if delta > 0 or np.random.random() < np.exp(delta / T):
                current_fitness = new_fitness
                if new_fitness > best_fitness:
                    best_fitness = new_fitness
                    best_solution = solution.copy()
            else:
                # restore previous state
                solution[:] = old_solution
                current_fitness = old_fitness

            # T gradually drops
            T *= cooling_rate

            # debug
            if verbose and step % 100 == 0:
                print(f"Step: {step:4d} | Best_fitness: {best_fitness:6d} | T: {T:.4f}")

        print("\n=== FINAL RESULT ===")
        print(f"Best value found: {best_fitness}")
        print(f"Best configuration:\n{best_solution}")

# %% [markdown]
# ## TEST PROBLEMS

# %%
# Problem 1:
rng = np.random.default_rng(seed=42)
NUM_KNAPSACKS = 3
NUM_ITEMS = 20
NUM_DIMENSIONS = 2
VALUES = rng.integers(0, 100, size=NUM_ITEMS)
WEIGHTS = rng.integers(0, 100, size=(NUM_ITEMS, NUM_DIMENSIONS))
CONSTRAINTS = rng.integers(0, 100 * NUM_ITEMS // NUM_KNAPSACKS, size=(NUM_KNAPSACKS,NUM_DIMENSIONS))

print("=== PROBLEM 1 ===")
solver = Solution(NUM_KNAPSACKS, NUM_ITEMS, NUM_DIMENSIONS, VALUES, WEIGHTS, CONSTRAINTS)
solver.resolve(max_steps=5000, initial_temp=10.0, cooling_rate=0.99)
# Out:
# === PROBLEM 1 ===
# Step:    0 | Best_fitness:     69 | T: 9.9000
# Step:  100 | Best_fitness:    882 | T: 3.6237
# Step:  200 | Best_fitness:   1037 | T: 1.3264
# Step:  300 | Best_fitness:   1037 | T: 0.4855
# Step:  400 | Best_fitness:   1037 | T: 0.1777
# Step:  500 | Best_fitness:   1037 | T: 0.0650
# Step:  600 | Best_fitness:   1037 | T: 0.0238
# Step:  700 | Best_fitness:   1037 | T: 0.0087
# Step:  800 | Best_fitness:   1037 | T: 0.0032
# Step:  900 | Best_fitness:   1037 | T: 0.0012
# Step: 1000 | Best_fitness:   1037 | T: 0.0004
# Step: 1100 | Best_fitness:   1037 | T: 0.0002
# Step: 1200 | Best_fitness:   1037 | T: 0.0001
# Step: 1300 | Best_fitness:   1037 | T: 0.0000
# Step: 1400 | Best_fitness:   1037 | T: 0.0000
# Step: 1500 | Best_fitness:   1037 | T: 0.0000
# Step: 1600 | Best_fitness:   1037 | T: 0.0000
# Step: 1700 | Best_fitness:   1037 | T: 0.0000
# Step: 1800 | Best_fitness:   1037 | T: 0.0000
# Step: 1900 | Best_fitness:   1037 | T: 0.0000
# Step: 2000 | Best_fitness:   1037 | T: 0.0000
# Step: 2100 | Best_fitness:   1037 | T: 0.0000
# Step: 2200 | Best_fitness:   1037 | T: 0.0000
# Step: 2300 | Best_fitness:   1037 | T: 0.0000
# Step: 2400 | Best_fitness:   1037 | T: 0.0000
# Step: 2500 | Best_fitness:   1037 | T: 0.0000
# Step: 2600 | Best_fitness:   1037 | T: 0.0000
# Step: 2700 | Best_fitness:   1037 | T: 0.0000
# Step: 2800 | Best_fitness:   1037 | T: 0.0000
# Step: 2900 | Best_fitness:   1037 | T: 0.0000
# Step: 3000 | Best_fitness:   1037 | T: 0.0000
# Step: 3100 | Best_fitness:   1037 | T: 0.0000
# Step: 3200 | Best_fitness:   1037 | T: 0.0000
# Step: 3300 | Best_fitness:   1037 | T: 0.0000
# Step: 3400 | Best_fitness:   1037 | T: 0.0000
# Step: 3500 | Best_fitness:   1037 | T: 0.0000
# Step: 3600 | Best_fitness:   1037 | T: 0.0000
# Step: 3700 | Best_fitness:   1037 | T: 0.0000
# Step: 3800 | Best_fitness:   1037 | T: 0.0000
# Step: 3900 | Best_fitness:   1037 | T: 0.0000
# Step: 4000 | Best_fitness:   1037 | T: 0.0000
# Step: 4100 | Best_fitness:   1037 | T: 0.0000
# Step: 4200 | Best_fitness:   1037 | T: 0.0000
# Step: 4300 | Best_fitness:   1037 | T: 0.0000
# Step: 4400 | Best_fitness:   1037 | T: 0.0000
# Step: 4500 | Best_fitness:   1037 | T: 0.0000
# Step: 4600 | Best_fitness:   1037 | T: 0.0000
# Step: 4700 | Best_fitness:   1037 | T: 0.0000
# Step: 4800 | Best_fitness:   1037 | T: 0.0000
# Step: 4900 | Best_fitness:   1037 | T: 0.0000
#
# === FINAL RESULT ===
# Best value found: 1037
# Best configuration:
# [[False  True  True False  True  True  True False False False  True False
#    True False False  True False False  True False]
#  [False False False  True False False False False False  True False  True
#   False False  True False  True False False False]
#  [False False False False False False False  True False False False False
#   False  True False False False  True False  True]]

# %%
# Problem 2:
rng = np.random.default_rng(seed=42)
NUM_KNAPSACKS = 10
NUM_ITEMS = 100
NUM_DIMENSIONS = 10
VALUES = rng.integers(0, 1000, size=NUM_ITEMS)
WEIGHTS = rng.integers(0, 1000, size=(NUM_ITEMS, NUM_DIMENSIONS))
CONSTRAINTS = rng.integers(1000 * 2, 1000 * NUM_ITEMS // NUM_KNAPSACKS, size=(NUM_KNAPSACKS,NUM_DIMENSIONS))

print("=== PROBLEM 2 ===")
solver = Solution(NUM_KNAPSACKS, NUM_ITEMS, NUM_DIMENSIONS, VALUES, WEIGHTS, CONSTRAINTS)
solver.resolve(max_steps=5000, initial_temp=10.0, cooling_rate=0.99)
# Out:
# === PROBLEM 2 ===
# Step:    0 | Best_fitness:    450 | T: 9.9000
# Step:  100 | Best_fitness:  24310 | T: 3.6237
# Step:  200 | Best_fitness:  28147 | T: 1.3264
# Step:  300 | Best_fitness:  30222 | T: 0.4855
# Step:  400 | Best_fitness:  31501 | T: 0.1777
# Step:  500 | Best_fitness:  32464 | T: 0.0650
# Step:  600 | Best_fitness:  32464 | T: 0.0238
# Step:  700 | Best_fitness:  32464 | T: 0.0087
# Step:  800 | Best_fitness:  32553 | T: 0.0032
# Step:  900 | Best_fitness:  32553 | T: 0.0012
# Step: 1000 | Best_fitness:  32770 | T: 0.0004
# Step: 1100 | Best_fitness:  32770 | T: 0.0002
# Step: 1200 | Best_fitness:  33216 | T: 0.0001
# Step: 1300 | Best_fitness:  33216 | T: 0.0000
# Step: 1400 | Best_fitness:  33216 | T: 0.0000
# Step: 1500 | Best_fitness:  33216 | T: 0.0000
# Step: 1600 | Best_fitness:  33216 | T: 0.0000
# Step: 1700 | Best_fitness:  33216 | T: 0.0000
# Step: 1800 | Best_fitness:  33216 | T: 0.0000
# Step: 1900 | Best_fitness:  33216 | T: 0.0000
# Step: 2000 | Best_fitness:  33216 | T: 0.0000
# Step: 2100 | Best_fitness:  33216 | T: 0.0000
# Step: 2200 | Best_fitness:  33216 | T: 0.0000
# Step: 2300 | Best_fitness:  33216 | T: 0.0000
# Step: 2400 | Best_fitness:  33216 | T: 0.0000
# Step: 2500 | Best_fitness:  33216 | T: 0.0000
# Step: 2600 | Best_fitness:  33216 | T: 0.0000
# Step: 2700 | Best_fitness:  33216 | T: 0.0000
# Step: 2800 | Best_fitness:  33216 | T: 0.0000
# Step: 2900 | Best_fitness:  33216 | T: 0.0000
# Step: 3000 | Best_fitness:  33216 | T: 0.0000
# Step: 3100 | Best_fitness:  33216 | T: 0.0000
# Step: 3200 | Best_fitness:  33216 | T: 0.0000
# Step: 3300 | Best_fitness:  33216 | T: 0.0000
# Step: 3400 | Best_fitness:  33216 | T: 0.0000
# Step: 3500 | Best_fitness:  33216 | T: 0.0000
# Step: 3600 | Best_fitness:  33216 | T: 0.0000
# Step: 3700 | Best_fitness:  33216 | T: 0.0000
# Step: 3800 | Best_fitness:  33216 | T: 0.0000
# Step: 3900 | Best_fitness:  33216 | T: 0.0000
# Step: 4000 | Best_fitness:  33216 | T: 0.0000
# Step: 4100 | Best_fitness:  33216 | T: 0.0000
# Step: 4200 | Best_fitness:  33216 | T: 0.0000
# Step: 4300 | Best_fitness:  33216 | T: 0.0000
# Step: 4400 | Best_fitness:  33216 | T: 0.0000
# Step: 4500 | Best_fitness:  33216 | T: 0.0000
# Step: 4600 | Best_fitness:  33216 | T: 0.0000
# Step: 4700 | Best_fitness:  33216 | T: 0.0000
# Step: 4800 | Best_fitness:  33216 | T: 0.0000
# Step: 4900 | Best_fitness:  33216 | T: 0.0000
#
# === FINAL RESULT ===
# Best value found: 33216
# Best configuration:
# [[False  True False False False False False False False  True False  True
#   False False False False False False False False False False False False
#   False False False False  True False False False False False False False
#   False  True False False False False False False False False False False
#   False False False False False False False False False False False  True
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False]
#  [ True False False False False False False False False False False False
#   False False False False False  True False False  True False False False
#   False False False False False False False False False False  True False
#   False False False False  True False False False False False False False
#   False  True False False False False False False False False False False
#   False False False False False False False False  True False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False]
#  [False False False False False False False  True False False False False
#   False False False False False False False False False False False False
#    True False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False  True False False False False False False False False False
#   False  True False False False False False False False False False False
#   False False False False False False  True False  True False False False
#   False False False False False False False False False False False False
#   False False False False]
#  [False False False False False False False False False False False False
#   False False False False False False False False False False  True False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False  True  True False False False False False False False False
#   False  True False False False False False False False False False False
#   False False False  True False False False False  True False False False
#    True False False False]
#  [False False  True False False False False False  True False False False
#   False False False False  True False False False False False False False
#   False False False False False False False  True False False False False
#    True False False False False False False False  True False False False
#   False False False False False False  True False False  True False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False  True False False
#   False False False False]
#  [False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False  True False False False False
#   False False False False False False False False False False False False
#   False False False False False  True False False False False  True  True
#   False False False False False False False False False False False  True
#   False  True False False False  True False False False False False False
#   False False False False]
#  [False False False False  True False False False False False False False
#   False False False False False False False False False False False False
#   False False  True False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#    True False  True False False False False False False False False False
#   False False False False False False  True False False False False False
#   False False False False]
#  [False False False False False False  True False False False False False
#   False False False False False False False False False  True False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False  True False False False False
#   False False False False  True False False False False False False False
#   False False False False]
#  [False False False False False False False False False False  True False
#   False False False False False False False  True False False False  True
#   False False False False False False False False False False False  True
#   False False False False False False False False False False False False
#   False False False  True False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False]
#  [False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False  True False False False False False False False False False False
#   False False False False False  True False False False False False  True
#   False False False False False False False False  True False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False  True False False  True  True
#   False  True False False]]

# %%
# Problem 3:
rng = np.random.default_rng(seed=42)
NUM_KNAPSACKS = 100
NUM_ITEMS = 5000
NUM_DIMENSIONS = 100
VALUES = rng.integers(0, 1000, size=NUM_ITEMS)
WEIGHTS = rng.integers(0, 1000, size=(NUM_ITEMS, NUM_DIMENSIONS))
CONSTRAINTS = rng.integers(1000 * 10, 1000 * 2 * NUM_ITEMS // NUM_KNAPSACKS, size=(NUM_KNAPSACKS,NUM_DIMENSIONS))

print("=== PROBLEM 3 ===")
solver = Solution(NUM_KNAPSACKS, NUM_ITEMS, NUM_DIMENSIONS, VALUES, WEIGHTS, CONSTRAINTS)
solver.resolve(max_steps=10000, initial_temp=10.0, cooling_rate=0.99)
# Out:
# === PROBLEM 3 ===
# Step:    0 | Best_fitness:    887 | T: 9.9000
# Step:  100 | Best_fitness:  53865 | T: 3.6237
# Step:  200 | Best_fitness: 104475 | T: 1.3264
# Step:  300 | Best_fitness: 150945 | T: 0.4855
# Step:  400 | Best_fitness: 194240 | T: 0.1777
# Step:  500 | Best_fitness: 238412 | T: 0.0650
# Step:  600 | Best_fitness: 282950 | T: 0.0238
# Step:  700 | Best_fitness: 324723 | T: 0.0087
# Step:  800 | Best_fitness: 365661 | T: 0.0032
# Step:  900 | Best_fitness: 404509 | T: 0.0012
# Step: 1000 | Best_fitness: 441607 | T: 0.0004
# Step: 1100 | Best_fitness: 489008 | T: 0.0002
# Step: 1200 | Best_fitness: 523791 | T: 0.0001
# Step: 1300 | Best_fitness: 565886 | T: 0.0000
# Step: 1400 | Best_fitness: 602763 | T: 0.0000
# Step: 1500 | Best_fitness: 644818 | T: 0.0000
# Step: 1600 | Best_fitness: 678149 | T: 0.0000
# Step: 1700 | Best_fitness: 717447 | T: 0.0000
# Step: 1800 | Best_fitness: 754369 | T: 0.0000
# Step: 1900 | Best_fitness: 782530 | T: 0.0000
# Step: 2000 | Best_fitness: 807201 | T: 0.0000
# Step: 2100 | Best_fitness: 836561 | T: 0.0000
# Step: 2200 | Best_fitness: 864645 | T: 0.0000
# Step: 2300 | Best_fitness: 890916 | T: 0.0000
# Step: 2400 | Best_fitness: 910970 | T: 0.0000
# Step: 2500 | Best_fitness: 925331 | T: 0.0000
# Step: 2600 | Best_fitness: 943858 | T: 0.0000
# Step: 2700 | Best_fitness: 958528 | T: 0.0000
# Step: 2800 | Best_fitness: 970143 | T: 0.0000
# Step: 2900 | Best_fitness: 983325 | T: 0.0000
# Step: 3000 | Best_fitness: 992382 | T: 0.0000
# Step: 3100 | Best_fitness: 1000782 | T: 0.0000
# Step: 3200 | Best_fitness: 1011788 | T: 0.0000
# Step: 3300 | Best_fitness: 1023022 | T: 0.0000
# Step: 3400 | Best_fitness: 1030740 | T: 0.0000
# Step: 3500 | Best_fitness: 1039302 | T: 0.0000
# Step: 3600 | Best_fitness: 1044306 | T: 0.0000
# Step: 3700 | Best_fitness: 1049788 | T: 0.0000
# Step: 3800 | Best_fitness: 1055323 | T: 0.0000
# Step: 3900 | Best_fitness: 1057618 | T: 0.0000
# Step: 4000 | Best_fitness: 1062649 | T: 0.0000
# Step: 4100 | Best_fitness: 1064582 | T: 0.0000
# Step: 4200 | Best_fitness: 1070602 | T: 0.0000
# Step: 4300 | Best_fitness: 1075144 | T: 0.0000
# Step: 4400 | Best_fitness: 1080621 | T: 0.0000
# Step: 4500 | Best_fitness: 1083129 | T: 0.0000
# Step: 4600 | Best_fitness: 1085095 | T: 0.0000
# Step: 4700 | Best_fitness: 1085987 | T: 0.0000
# Step: 4800 | Best_fitness: 1088118 | T: 0.0000
# Step: 4900 | Best_fitness: 1090599 | T: 0.0000
# Step: 5000 | Best_fitness: 1090893 | T: 0.0000
# Step: 5100 | Best_fitness: 1093970 | T: 0.0000
# Step: 5200 | Best_fitness: 1094471 | T: 0.0000
# Step: 5300 | Best_fitness: 1096057 | T: 0.0000
# Step: 5400 | Best_fitness: 1097921 | T: 0.0000
# Step: 5500 | Best_fitness: 1102108 | T: 0.0000
# Step: 5600 | Best_fitness: 1105005 | T: 0.0000
# Step: 5700 | Best_fitness: 1105247 | T: 0.0000
# Step: 5800 | Best_fitness: 1106872 | T: 0.0000
# Step: 5900 | Best_fitness: 1109789 | T: 0.0000
# Step: 6000 | Best_fitness: 1111118 | T: 0.0000
# Step: 6100 | Best_fitness: 1113814 | T: 0.0000
# Step: 6200 | Best_fitness: 1115393 | T: 0.0000
# Step: 6300 | Best_fitness: 1119741 | T: 0.0000
# Step: 6400 | Best_fitness: 1122134 | T: 0.0000
# Step: 6500 | Best_fitness: 1122947 | T: 0.0000
# Step: 6600 | Best_fitness: 1124561 | T: 0.0000
# Step: 6700 | Best_fitness: 1126320 | T: 0.0000
# Step: 6800 | Best_fitness: 1128429 | T: 0.0000
# Step: 6900 | Best_fitness: 1132956 | T: 0.0000
# Step: 7000 | Best_fitness: 1134349 | T: 0.0000
# Step: 7100 | Best_fitness: 1135808 | T: 0.0000
# Step: 7200 | Best_fitness: 1137494 | T: 0.0000
# Step: 7300 | Best_fitness: 1138872 | T: 0.0000
# Step: 7400 | Best_fitness: 1141152 | T: 0.0000
# Step: 7500 | Best_fitness: 1142664 | T: 0.0000
# Step: 7600 | Best_fitness: 1144478 | T: 0.0000
# Step: 7700 | Best_fitness: 1144744 | T: 0.0000
# Step: 7800 | Best_fitness: 1146252 | T: 0.0000
# Step: 7900 | Best_fitness: 1148701 | T: 0.0000
# Step: 8000 | Best_fitness: 1151257 | T: 0.0000
# Step: 8100 | Best_fitness: 1152916 | T: 0.0000
# Step: 8200 | Best_fitness: 1154392 | T: 0.0000
# Step: 8300 | Best_fitness: 1156074 | T: 0.0000
# Step: 8400 | Best_fitness: 1158985 | T: 0.0000
# Step: 8500 | Best_fitness: 1160600 | T: 0.0000
# Step: 8600 | Best_fitness: 1163159 | T: 0.0000
# Step: 8700 | Best_fitness: 1166150 | T: 0.0000
# Step: 8800 | Best_fitness: 1167096 | T: 0.0000
# Step: 8900 | Best_fitness: 1168283 | T: 0.0000
# Step: 9000 | Best_fitness: 1169843 | T: 0.0000
# Step: 9100 | Best_fitness: 1171915 | T: 0.0000
# Step: 9200 | Best_fitness: 1175005 | T: 0.0000
# Step: 9300 | Best_fitness: 1175699 | T: 0.0000
# Step: 9400 | Best_fitness: 1176186 | T: 0.0000
# Step: 9500 | Best_fitness: 1176479 | T: 0.0000
# Step: 9600 | Best_fitness: 1179423 | T: 0.0000
# Step: 9700 | Best_fitness: 1179975 | T: 0.0000
# Step: 9800 | Best_fitness: 1180999 | T: 0.0000
# Step: 9900 | Best_fitness: 1181115 | T: 0.0000
#
# === FINAL RESULT ===
# Best value found: 1183965
# Best configuration:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False  True False ... False False False]]
